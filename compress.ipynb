# %%
import os
import cv2
import numpy as np
from PIL import Image

# %%
# Define input and output folder paths
input_folder = './images'  # Folder containing the images
output_folder = 'compressed_images'  # Folder to save compressed images
os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

# %%
# Define compression factors (you can adjust these if needed)
downscale_factor = 0.3  # Resize image to 30% of the original size
compression_quality = 30  # JPEG quality (lower means more compression)

# Supported image formats (JPEG, JPG, PNG, etc.)
supported_formats = ['.jpg', '.jpeg', '.png']

# %%
# Function to process and compress a single image
def process_image(input_image_path, output_image_path):
    # Load the image using OpenCV
    image = cv2.imread(input_image_path)

    # Convert the image to grayscale to reduce file size and enhance text
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(gray_image)

    # Downscale the image to the specified percentage of the original size
    new_width = int(enhanced_image.shape[1] * downscale_factor)
    new_height = int(enhanced_image.shape[0] * downscale_factor)
    resized_image = cv2.resize(enhanced_image, (new_width, new_height), interpolation=cv2.INTER_AREA)

    # Save the compressed image with enhanced contrast
    cv2.imwrite(output_image_path, resized_image, [int(cv2.IMWRITE_JPEG_QUALITY), compression_quality])

# %%
# Iterate over all files in the input folder
for filename in os.listdir(input_folder):
    # Check if the file is an image by verifying its extension
    if any(filename.lower().endswith(ext) for ext in supported_formats):
        input_image_path = os.path.join(input_folder, filename)  # Full input path
        output_image_path = os.path.join(output_folder, filename)  # Full output path
        
        # Process and compress the image
        process_image(input_image_path, output_image_path)

        print(f"Compressed and enhanced image saved to: {output_image_path}")

print("Processing complete for all images in the folder.")
# Out:
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_011.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_013.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_015.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_016.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_017.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_023.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_024.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_025.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_026.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_027.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_028.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_029.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_030.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_031.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_032.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_033.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_034.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_035.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_036.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_037.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_038.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_039.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_040.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_041.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_042.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_043.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_044.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_045.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_046.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_047.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_048.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_049.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_050.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_051.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_052.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_053.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_054.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_055.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_056.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_057.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_058.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_059.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_060.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_061.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_062.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_063.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_064.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_065.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_066.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_067.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_068.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_069.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_070.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_071.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_072.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_073.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_074.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_075.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_076.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_077.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_078.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_079.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_080.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_081.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_082.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_083.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_084.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_085.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_086.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_087.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_088.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_089.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_090.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_091.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_092.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_093.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_094.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_095.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_096.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_097.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_098.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_099.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_100.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_101.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_102.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_103.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_104.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_105.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_106.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_107.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_108.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_109.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_110.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_111.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_112.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_113.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_114.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_115.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_116.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_117.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_118.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_119.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_120.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_121.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_122.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_123.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_124.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_125.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_126.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_127.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_128.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_129.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_130.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_131.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_132.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_133.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_134.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_135.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_136.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_137.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_138.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_139.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_140.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_141.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_142.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1_143.jpg
# Compressed and enhanced image saved to: compressed_images/dupickens_a-1